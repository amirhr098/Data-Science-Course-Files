# %%
from pyidd import PyIDD
import pandas as pd
from scipy.stats import norm, beta

# %%
whData = pd.read_csv('weight-height.csv')
whData.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
beta.fit(whData['Height'])
# Out:
# (5.958319408062067, 6.498169312519742, 52.87268950557022, 28.213574971918785)

# %%
fd = PyIDD(verbose=1)
fd = fd.fit(whData['Height'])
# Out:
# distribution: alpha_gen
# #SSE: 0.01384947524805342
# #params: (27.296647864591165, -38.52329956549539, 2859.505141777513)
# distribution: anglit_gen
# #SSE: 0.0746279980933079
# #params: (66.63055856120918, 15.751932398587277)
# distribution: arcsine_gen
# #SSE: 0.6187926784866435
# #params: (54.263133325097094, 24.73562772408398)
# distribution: argus_gen
# #SSE: 0.18225620530985204
# #params: (1.0851456590077807e-05, 54.07906629787854, 24.920486510482675)
# distribution: beta_gen
# #SSE: 0.008965160324321634
# #params: (5.958319408062067, 6.498169312519742, 52.87268950557022, 28.213574971918785)
# distribution: betaprime_gen
# #SSE: 0.013366061991254181
# #params: (10256.334272674798, 668.3262278195261, -30.08504153585232, 6.275606795305668)
# distribution: bradford_gen
# #SSE: 0.254067154799108
# #params: (0.094370821456152, 54.26313332402296, 24.768495525702335)
# distribution: burr_gen
# #SSE: 0.03257799447264244
# #params: (101.38269659463032, 198817.43735391146, -301.96121223163664, 324.7703980507414)
# distribution: burr12_gen
# #SSE: 0.021807646162760385
# #params: (25.55700372402798, 1.6291303763857143, 0.08456725164205202, 68.03031692824442)
# distribution: cauchy_gen
# #SSE: 0.07302482073195296
# #params: (66.29957639165795, 2.5413090777714977)
# distribution: chi_gen
# #SSE: 0.012944066733639065
# #params: (26.690503261701846, 38.35627781117064, 5.472841918922885)
# distribution: chi2_gen
# #SSE: 0.013445711823182296
# #params: (171.7905126394694, 30.560798547803756, 0.20842915501849169)
# distribution: cosine_gen
# #SSE: 0.02162885201971962
# #params: (66.6243150494602, 3.9422943770889525)
# distribution: crystalball_gen
# #SSE: 0.013522599670129152
# #params: (21130.707710152445, 23259.33831203959, 66.36755970751389, 3.8473355106219254)
# distribution: dgamma_gen
# #SSE: 0.031812051606803005
# #params: (1.530300595506257, 66.00955946339363, 2.0762529709436928)
# distribution: dweibull_gen
# #SSE: 0.02262349634492224
# #params: (1.3794314232631693, 66.49346671005445, 3.4504622622027945)
# distribution: erlang_gen
# #SSE: 0.013315054451541552
# #params: (1352.7432675962764, -75.17355377015596, 0.1046314430244692)
# distribution: expon_gen
# #SSE: 0.3927447375067035
# #params: (54.2631333250971, 12.104426429724143)
# distribution: exponnorm_gen
# #SSE: 0.013520250348727557
# #params: (0.10403303955047874, 65.96946118464818, 3.8266848506705538)
# distribution: exponweib_gen
# #SSE: 2.8504822157897816
# #params: (1.563789165113263, 0.3024156264140138, 54.263133325097094, 0.7970112519326721)
# distribution: exponpow_gen
# #SSE: 2.353192851281696
# #params: (0.1553616412575322, 54.263133325097094, 1.5848343280120842)
# distribution: f_gen
# #SSE: 0.013481815649029814
# #params: (4486.9184101071605, 1004.1626081170775, -11.625207778655707, 77.83756048645813)
# distribution: fatiguelife_gen
# #SSE: 0.013346956502219565
# #params: (0.02492051906385845, -87.94893721457916, 154.26980994303773)
# distribution: fisk_gen
# #SSE: 0.023575575219455292
# #params: (29.561884006810097, -0.26431844485867717, 66.55207124427447)
# distribution: foldcauchy_gen
# #SSE: 0.06750938402138262
# #params: (4.62192837074969, 54.26313326691265, 2.604140990621097)
# distribution: foldnorm_gen
# #SSE: 0.013486926325938682
# #params: (3.1438908139144024, 54.26313115703228, 3.8498681869108493)
# distribution: genlogistic_gen
# #SSE: 0.02180833854676626
# #params: (1.5224961534976758, 64.80200172356555, 2.547594512667134)
# distribution: gennorm_gen
# #SSE: 0.007123643500979819
# #params: (2.731538109838218, 66.39424772516303, 6.144510605158612)
# distribution: genpareto_gen
# #SSE: 0.47257565219086395
# #params: (-1.8917054983541757, -0.9625788042360882, 151.26327087630267)
# distribution: weibull_max_gen
# #SSE: 3.133202866776807
# #params: (0.3497283307874748, 78.99874234638962, 1.3141441547432273)
# distribution: wrapcauchy_gen
# #SSE: 0.26077156387399025
# #params: (2.7899076790194207e-09, 54.263133293693585, 4.589653278202993)
# distribution: genexpon_gen
# #SSE: 0.1257490199086549
# #params: (0.010554321181139158, 1.568984479810747, 0.03312695332845303, 54.23289266771246, 2.0365306823500076)
# distribution: genextreme_gen
# #SSE: 0.010553212310968299
# #params: (0.25773198743188996, 64.96072497648117, 3.7891653114530333)
# distribution: gausshyper_gen
# #SSE: 0.05452282930308807
# #params: (2.1136730111422093, 3.3109868691491955, 2.9487733114383463, -0.6020448223447268, 54.2598693998606, 24.743063010401258)
# distribution: gamma_gen
# #SSE: 0.013344427918595057
# #params: (1341.378443638302, -74.52315478428335, 0.10503423981240032)
# distribution: gengamma_gen
# #SSE: 2.169070464174451
# #params: (1.7919193734793701, 0.3141974173931601, 54.263133325097094, 0.49300089985581874)
# distribution: genhalflogistic_gen
# #SSE: 0.1633453968285414
# #params: (0.49012250599163143, 54.2631333125008, 12.126371594592118)
# distribution: geninvgauss_gen
# #SSE: 0.0310410657496953
# #params: (6.139694996673713, 0.0004950781311869011, 54.238985435411436, 0.0004889685070223362)
# distribution: gilbrat_gen
# #SSE: 0.27327667085249085
# #params: (54.255125640407265, 11.414493136044385)
# distribution: gompertz_gen
# #SSE: 0.02862046458906306
# #params: (0.03275859775067039, 54.26313327466269, 4.030067388801429)
# distribution: gumbel_r_gen
# #SSE: 0.028168289742191564
# #params: (64.4556953925733, 3.6650934193855753)
# distribution: gumbel_l_gen
# #SSE: 0.03605729842988094
# #params: (68.29675493727606, 3.751617045440848)
# distribution: halfcauchy_gen
# #SSE: 0.3503575318939257
# #params: (54.263133324687004, 11.534492819779722)
# distribution: halflogistic_gen
# #SSE: 0.31012456586840764
# #params: (54.263133320241664, 8.017301289380597)
# distribution: halfnorm_gen
# #SSE: 0.2963141667525843
# #params: (54.26313332190364, 12.701773368495772)
# distribution: halfgennorm_gen
# #SSE: 0.1802935350827984
# #params: (11.188659637043115, 54.263131043873656, 19.924974843122918)
# distribution: hypsecant_gen
# #SSE: 0.033528302809045285
# #params: (66.33390018603858, 2.7155950653441208)
# distribution: invgamma_gen
# #SSE: 0.013351910799996503
# #params: (938.6851306117446, -51.514850330924595, 110532.33544307368)
# distribution: invgauss_gen
# #SSE: 0.01701996726397926
# #params: (0.031284967060024454, 43.730470122605624, 722.532021145842)
# distribution: invweibull_gen
# #SSE: 0.02809821443067919
# #params: (531607942.52734107, -1950022420.2091713, 1950022484.666325)
# distribution: johnsonsb_gen
# #SSE: 0.008685818261891545
# #params: (0.14602102150132112, 1.8714362469357462, 51.57995101936224, 30.697481982166153)
# distribution: johnsonsu_gen
# #SSE: 0.013349930792196131
# #params: (-45.302494388241286, 38.403105413078606, -55.84952943315754, 82.9477236629524)
# distribution: kappa4_gen
# #SSE: 0.2537924789188135
# #params: (1.0421777291800232, 0.7751995311754634, 53.458131598395184, 19.799356232590995)
# distribution: kappa3_gen
# #SSE: 0.18075050935378226
# #params: (24.46822628146532, 53.86198569668065, 17.890457043520172)
# distribution: ksone_gen
# #SSE: 0.25415757148990065
# #params: (1.0808339293671925, 54.26313328467138, 24.735610163404793)
# distribution: kstwo_gen
# distribution: kstwobign_gen
# #SSE: 0.03375960517130829
# #params: (50.797575175003935, 17.918080490552107)
# distribution: laplace_gen
# #SSE: 0.07165678338146321
# #params: (66.31807008178464, 3.1677731466084778)
# distribution: levy_gen
# #SSE: 0.3484724322288244
# #params: (54.18324079049515, 10.517123484736047)
# distribution: levy_l_gen
# #SSE: 0.35856433367967044
# #params: (79.0833155381151, 11.055163317958115)
# distribution: logistic_gen
# #SSE: 0.02373898895953753
# #params: (66.34524255838932, 2.2505797409274106)
# distribution: loggamma_gen
# #SSE: 0.01348251401735421
# #params: (816.3669261194073, -672.9649698482895, 110.27810154317172)
# distribution: loglaplace_gen
# #SSE: 0.07139071559258657
# #params: (20.996289188772238, -0.2424604361613356, 66.56059317690881)
# distribution: lognorm_gen
# #SSE: 0.013319275898093574
# #params: (0.025604849307773056, -83.8820510796117, 150.20104876196217)
# distribution: reciprocal_gen
# #SSE: 0.5810348852080492
# #params: (0.9015482215897133, 1.6009849280375819, 0.0021890907748951093, 7.134297062689321e-31)
# distribution: lomax_gen
# #SSE: 0.41297615789646835
# #params: (8747519323.970955, 54.26313329617227, 597783055571.4113)
# distribution: maxwell_gen
# #SSE: 0.03966133582645871
# #params: (54.2575272865778, 7.3361219126909125)
# distribution: mielke_gen
# #SSE: 0.023287795842477546
# #params: (31.85675532678141, 28.840225744678303, -0.8484788186068569, 66.78377372316626)
# distribution: moyal_gen
# #SSE: 0.04513228519006873
# #params: (63.68089735607353, 2.5021338829613184)
# distribution: nakagami_gen
# #SSE: 0.01294406629495537
# #params: (13.345207937635898, 38.356323382618285, 28.274216815760788)
# distribution: norm_gen
# #SSE: 0.013522595406718674
# #params: (66.36755975482124, 3.84733573955754)
# distribution: norminvgauss_gen
# #SSE: 0.013320972910154369
# #params: (9185.486098001998, 9171.520276628467, -20.164144943591737, 4.7769231220053765)
# distribution: pareto_gen
# #SSE: 0.43672347659518007
# #params: (5.021255376502834, -0.15908507286089554, 54.422218397199316)
# distribution: pearson3_gen
# #SSE: 0.013293019889042898
# #params: (0.07672208958378723, 66.36759067295552, 3.848039810580856)
# distribution: powerlaw_gen
# #SSE: 0.2479569385105405
# #params: (1.2916431520537155, 54.26195674597115, 24.736785689323206)
# distribution: powerlognorm_gen
# #SSE: 0.013507949719387357
# #params: (1.5176633916121853, 0.06768301051650397, 2.1854907275476125, 65.61958665820421)
# distribution: powernorm_gen
# #SSE: 0.01267752677213293
# #params: (0.5076465644365958, 64.23403240367726, 3.100458470309424)
# distribution: rdist_gen
# #SSE: 0.009238423022783236
# #params: (12.573380315404787, 66.39146880462053, 14.155373804342279)
# distribution: rayleigh_gen
# #SSE: 0.12970746228252583
# #params: (61.769424142823986, 4.239389307388162)
# distribution: rice_gen
# #SSE: 0.012640682566973382
# #params: (2.8835376655889426, 54.13540510485447, 3.99261270539926)
# distribution: recipinvgauss_gen
# #SSE: 0.013377202111918814
# #params: (0.007556507143388709, 21.67349397606725, 0.33544821720199003)
# distribution: semicircular_gen
# #SSE: 0.1456570961075389
# #params: (66.6308660369081, 12.36923848956295)
# distribution: skew_norm_gen
# #SSE: 0.013487531415884806
# #params: (0.5002971502346016, 64.8970066983245, 4.1188034130901245)
# distribution: t_gen
# #SSE: 0.013523457491207343
# #params: (3714882.3030038634, 66.36743701401312, 3.8472733885868724)
# distribution: trapezoid_gen
# #SSE: 0.3254235664639513
# #params: (1.0, 1.0, 51.78957242296785, 29.682730825551005)
# distribution: triang_gen
# #SSE: 0.04425787344310826
# #params: (0.4790841056111824, 54.25842881367677, 24.744979863618468)
# distribution: truncexpon_gen
# #SSE: 0.2765415582537544
# #params: (0.7758164065180074, 54.263108134983426, 31.88336055230612)
# distribution: truncnorm_gen
# #SSE: 0.5810348852080492
# #params: (0.9015482215897133, 1.6009849280375819, 0.0021890907748951093, 7.134297062689321e-31)
# distribution: tukeylambda_gen
# #SSE: 0.00934457241231599
# #params: (0.223264913086239, 66.39412288246041, 2.9768282160717465)
# distribution: uniform_gen
# #SSE: 0.2541575714899
# #params: (54.2631333250971, 24.735609021292504)
# distribution: vonmises_gen
# #SSE: 2.2327640871650902e+56
# #params: (1.037403543703737, 66.5041204019457, 1.8409258865943643e-28)
# distribution: vonmises_gen
# #SSE: 0.027082653640861227
# #params: (1.6098101054891676, 66.34624489132113, 4.027415098090106)
# distribution: wald_gen
# #SSE: 0.22730663132422935
# #params: (54.149485284858, 17.855476715622675)
# distribution: weibull_min_gen
# #SSE: 0.010677374812668616
# #params: (3.5661662135109324, 54.00638864117998, 13.731470628450356)

# %%
fd.plot(top=15)

# %%
fd.get_distributions()
# Out:
# [('gennorm_gen',
#   {'SSE': 0.007123643500979819,
#    'params': (2.731538109838218, 66.39424772516303, 6.144510605158612)}),
#  ('johnsonsb_gen',
#   {'SSE': 0.008685818261891545,
#    'params': (0.14602102150132112,
#     1.8714362469357462,
#     51.57995101936224,
#     30.697481982166153)}),
#  ('beta_gen',
#   {'SSE': 0.008965160324321634,
#    'params': (5.958319408062067,
#     6.498169312519742,
#     52.87268950557022,
#     28.213574971918785)}),
#  ('rdist_gen',
#   {'SSE': 0.009238423022783236,
#    'params': (12.573380315404787, 66.39146880462053, 14.155373804342279)}),
#  ('tukeylambda_gen',
#   {'SSE': 0.00934457241231599,
#    'params': (0.223264913086239, 66.39412288246041, 2.9768282160717465)}),
#  ('genextreme_gen',
#   {'SSE': 0.010553212310968299,
#    'params': (0.25773198743188996, 64.96072497648117, 3.7891653114530333)}),
#  ('weibull_min_gen',
#   {'SSE': 0.010677374812668616,
#    'params': (3.5661662135109324, 54.00638864117998, 13.731470628450356)}),
#  ('rice_gen',
#   {'SSE': 0.012640682566973382,
#    'params': (2.8835376655889426, 54.13540510485447, 3.99261270539926)}),
#  ('powernorm_gen',
#   {'SSE': 0.01267752677213293,
#    'params': (0.5076465644365958, 64.23403240367726, 3.100458470309424)}),
#  ('nakagami_gen',
#   {'SSE': 0.01294406629495537,
#    'params': (13.345207937635898, 38.356323382618285, 28.274216815760788)}),
#  ('chi_gen',
#   {'SSE': 0.012944066733639065,
#    'params': (26.690503261701846, 38.35627781117064, 5.472841918922885)}),
#  ('pearson3_gen',
#   {'SSE': 0.013293019889042898,
#    'params': (0.07672208958378723, 66.36759067295552, 3.848039810580856)}),
#  ('erlang_gen',
#   {'SSE': 0.013315054451541552,
#    'params': (1352.7432675962764, -75.17355377015596, 0.1046314430244692)}),
#  ('lognorm_gen',
#   {'SSE': 0.013319275898093574,
#    'params': (0.025604849307773056, -83.8820510796117, 150.20104876196217)}),
#  ('norminvgauss_gen',
#   {'SSE': 0.013320972910154369,
#    'params': (9185.486098001998,
#     9171.520276628467,
#     -20.164144943591737,
#     4.7769231220053765)}),
#  ('gamma_gen',
#   {'SSE': 0.013344427918595057,
#    'params': (1341.378443638302, -74.52315478428335, 0.10503423981240032)}),
#  ('fatiguelife_gen',
#   {'SSE': 0.013346956502219565,
#    'params': (0.02492051906385845, -87.94893721457916, 154.26980994303773)}),
#  ('johnsonsu_gen',
#   {'SSE': 0.013349930792196131,
#    'params': (-45.302494388241286,
#     38.403105413078606,
#     -55.84952943315754,
#     82.9477236629524)}),
#  ('invgamma_gen',
#   {'SSE': 0.013351910799996503,
#    'params': (938.6851306117446, -51.514850330924595, 110532.33544307368)}),
#  ('betaprime_gen',
#   {'SSE': 0.013366061991254181,
#    'params': (10256.334272674798,
#     668.3262278195261,
#     -30.08504153585232,
#     6.275606795305668)}),
#  ('recipinvgauss_gen',
#   {'SSE': 0.013377202111918814,
#    'params': (0.007556507143388709, 21.67349397606725, 0.33544821720199003)}),
#  ('chi2_gen',
#   {'SSE': 0.013445711823182296,
#    'params': (171.7905126394694, 30.560798547803756, 0.20842915501849169)}),
#  ('f_gen',
#   {'SSE': 0.013481815649029814,
#    'params': (4486.9184101071605,
#     1004.1626081170775,
#     -11.625207778655707,
#     77.83756048645813)}),
#  ('loggamma_gen',
#   {'SSE': 0.01348251401735421,
#    'params': (816.3669261194073, -672.9649698482895, 110.27810154317172)}),
#  ('foldnorm_gen',
#   {'SSE': 0.013486926325938682,
#    'params': (3.1438908139144024, 54.26313115703228, 3.8498681869108493)}),
#  ('skew_norm_gen',
#   {'SSE': 0.013487531415884806,
#    'params': (0.5002971502346016, 64.8970066983245, 4.1188034130901245)}),
#  ('powerlognorm_gen',
#   {'SSE': 0.013507949719387357,
#    'params': (1.5176633916121853,
#     0.06768301051650397,
#     2.1854907275476125,
#     65.61958665820421)}),
#  ('exponnorm_gen',
#   {'SSE': 0.013520250348727557,
#    'params': (0.10403303955047874, 65.96946118464818, 3.8266848506705538)}),
#  ('norm_gen',
#   {'SSE': 0.013522595406718674,
#    'params': (66.36755975482124, 3.84733573955754)}),
#  ('crystalball_gen',
#   {'SSE': 0.013522599670129152,
#    'params': (21130.707710152445,
#     23259.33831203959,
#     66.36755970751389,
#     3.8473355106219254)}),
#  ('t_gen',
#   {'SSE': 0.013523457491207343,
#    'params': (3714882.3030038634, 66.36743701401312, 3.8472733885868724)}),
#  ('alpha_gen',
#   {'SSE': 0.01384947524805342,
#    'params': (27.296647864591165, -38.52329956549539, 2859.505141777513)}),
#  ('invgauss_gen',
#   {'SSE': 0.01701996726397926,
#    'params': (0.031284967060024454, 43.730470122605624, 722.532021145842)}),
#  ('cosine_gen',
#   {'SSE': 0.02162885201971962,
#    'params': (66.6243150494602, 3.9422943770889525)}),
#  ('burr12_gen',
#   {'SSE': 0.021807646162760385,
#    'params': (25.55700372402798,
#     1.6291303763857143,
#     0.08456725164205202,
#     68.03031692824442)}),
#  ('genlogistic_gen',
#   {'SSE': 0.02180833854676626,
#    'params': (1.5224961534976758, 64.80200172356555, 2.547594512667134)}),
#  ('dweibull_gen',
#   {'SSE': 0.02262349634492224,
#    'params': (1.3794314232631693, 66.49346671005445, 3.4504622622027945)}),
#  ('mielke_gen',
#   {'SSE': 0.023287795842477546,
#    'params': (31.85675532678141,
#     28.840225744678303,
#     -0.8484788186068569,
#     66.78377372316626)}),
#  ('fisk_gen',
#   {'SSE': 0.023575575219455292,
#    'params': (29.561884006810097, -0.26431844485867717, 66.55207124427447)}),
#  ('logistic_gen',
#   {'SSE': 0.02373898895953753,
#    'params': (66.34524255838932, 2.2505797409274106)}),
#  ('vonmises_gen',
#   {'SSE': 0.027082653640861227,
#    'params': (1.6098101054891676, 66.34624489132113, 4.027415098090106)}),
#  ('invweibull_gen',
#   {'SSE': 0.02809821443067919,
#    'params': (531607942.52734107, -1950022420.2091713, 1950022484.666325)}),
#  ('gumbel_r_gen',
#   {'SSE': 0.028168289742191564,
#    'params': (64.4556953925733, 3.6650934193855753)}),
#  ('gompertz_gen',
#   {'SSE': 0.02862046458906306,
#    'params': (0.03275859775067039, 54.26313327466269, 4.030067388801429)}),
#  ('geninvgauss_gen',
#   {'SSE': 0.0310410657496953,
#    'params': (6.139694996673713,
#     0.0004950781311869011,
#     54.238985435411436,
#     0.0004889685070223362)}),
#  ('dgamma_gen',
#   {'SSE': 0.031812051606803005,
#    'params': (1.530300595506257, 66.00955946339363, 2.0762529709436928)}),
#  ('burr_gen',
#   {'SSE': 0.03257799447264244,
#    'params': (101.38269659463032,
#     198817.43735391146,
#     -301.96121223163664,
#     324.7703980507414)}),
#  ('hypsecant_gen',
#   {'SSE': 0.033528302809045285,
#    'params': (66.33390018603858, 2.7155950653441208)}),
#  ('kstwobign_gen',
#   {'SSE': 0.03375960517130829,
#    'params': (50.797575175003935, 17.918080490552107)}),
#  ('gumbel_l_gen',
#   {'SSE': 0.03605729842988094,
#    'params': (68.29675493727606, 3.751617045440848)}),
#  ('maxwell_gen',
#   {'SSE': 0.03966133582645871,
#    'params': (54.2575272865778, 7.3361219126909125)}),
#  ('triang_gen',
#   {'SSE': 0.04425787344310826,
#    'params': (0.4790841056111824, 54.25842881367677, 24.744979863618468)}),
#  ('moyal_gen',
#   {'SSE': 0.04513228519006873,
#    'params': (63.68089735607353, 2.5021338829613184)}),
#  ('gausshyper_gen',
#   {'SSE': 0.05452282930308807,
#    'params': (2.1136730111422093,
#     3.3109868691491955,
#     2.9487733114383463,
#     -0.6020448223447268,
#     54.2598693998606,
#     24.743063010401258)}),
#  ('foldcauchy_gen',
#   {'SSE': 0.06750938402138262,
#    'params': (4.62192837074969, 54.26313326691265, 2.604140990621097)}),
#  ('loglaplace_gen',
#   {'SSE': 0.07139071559258657,
#    'params': (20.996289188772238, -0.2424604361613356, 66.56059317690881)}),
#  ('laplace_gen',
#   {'SSE': 0.07165678338146321,
#    'params': (66.31807008178464, 3.1677731466084778)}),
#  ('cauchy_gen',
#   {'SSE': 0.07302482073195296,
#    'params': (66.29957639165795, 2.5413090777714977)}),
#  ('anglit_gen',
#   {'SSE': 0.0746279980933079,
#    'params': (66.63055856120918, 15.751932398587277)}),
#  ('genexpon_gen',
#   {'SSE': 0.1257490199086549,
#    'params': (0.010554321181139158,
#     1.568984479810747,
#     0.03312695332845303,
#     54.23289266771246,
#     2.0365306823500076)}),
#  ('rayleigh_gen',
#   {'SSE': 0.12970746228252583,
#    'params': (61.769424142823986, 4.239389307388162)}),
#  ('semicircular_gen',
#   {'SSE': 0.1456570961075389,
#    'params': (66.6308660369081, 12.36923848956295)}),
#  ('genhalflogistic_gen',
#   {'SSE': 0.1633453968285414,
#    'params': (0.49012250599163143, 54.2631333125008, 12.126371594592118)}),
#  ('halfgennorm_gen',
#   {'SSE': 0.1802935350827984,
#    'params': (11.188659637043115, 54.263131043873656, 19.924974843122918)}),
#  ('kappa3_gen',
#   {'SSE': 0.18075050935378226,
#    'params': (24.46822628146532, 53.86198569668065, 17.890457043520172)}),
#  ('argus_gen',
#   {'SSE': 0.18225620530985204,
#    'params': (1.0851456590077807e-05, 54.07906629787854, 24.920486510482675)}),
#  ('wald_gen',
#   {'SSE': 0.22730663132422935,
#    'params': (54.149485284858, 17.855476715622675)}),
#  ('powerlaw_gen',
#   {'SSE': 0.2479569385105405,
#    'params': (1.2916431520537155, 54.26195674597115, 24.736785689323206)}),
#  ('kappa4_gen',
#   {'SSE': 0.2537924789188135,
#    'params': (1.0421777291800232,
#     0.7751995311754634,
#     53.458131598395184,
#     19.799356232590995)}),
#  ('bradford_gen',
#   {'SSE': 0.254067154799108,
#    'params': (0.094370821456152, 54.26313332402296, 24.768495525702335)}),
#  ('uniform_gen',
#   {'SSE': 0.2541575714899, 'params': (54.2631333250971, 24.735609021292504)}),
#  ('ksone_gen',
#   {'SSE': 0.25415757148990065,
#    'params': (1.0808339293671925, 54.26313328467138, 24.735610163404793)}),
#  ('wrapcauchy_gen',
#   {'SSE': 0.26077156387399025,
#    'params': (2.7899076790194207e-09, 54.263133293693585, 4.589653278202993)}),
#  ('gilbrat_gen',
#   {'SSE': 0.27327667085249085,
#    'params': (54.255125640407265, 11.414493136044385)}),
#  ('truncexpon_gen',
#   {'SSE': 0.2765415582537544,
#    'params': (0.7758164065180074, 54.263108134983426, 31.88336055230612)}),
#  ('halfnorm_gen',
#   {'SSE': 0.2963141667525843,
#    'params': (54.26313332190364, 12.701773368495772)}),
#  ('halflogistic_gen',
#   {'SSE': 0.31012456586840764,
#    'params': (54.263133320241664, 8.017301289380597)}),
#  ('trapezoid_gen',
#   {'SSE': 0.3254235664639513,
#    'params': (1.0, 1.0, 51.78957242296785, 29.682730825551005)}),
#  ('levy_gen',
#   {'SSE': 0.3484724322288244,
#    'params': (54.18324079049515, 10.517123484736047)}),
#  ('halfcauchy_gen',
#   {'SSE': 0.3503575318939257,
#    'params': (54.263133324687004, 11.534492819779722)}),
#  ('levy_l_gen',
#   {'SSE': 0.35856433367967044,
#    'params': (79.0833155381151, 11.055163317958115)}),
#  ('expon_gen',
#   {'SSE': 0.3927447375067035,
#    'params': (54.2631333250971, 12.104426429724143)}),
#  ('lomax_gen',
#   {'SSE': 0.41297615789646835,
#    'params': (8747519323.970955, 54.26313329617227, 597783055571.4113)}),
#  ('pareto_gen',
#   {'SSE': 0.43672347659518007,
#    'params': (5.021255376502834, -0.15908507286089554, 54.422218397199316)}),
#  ('genpareto_gen',
#   {'SSE': 0.47257565219086395,
#    'params': (-1.8917054983541757, -0.9625788042360882, 151.26327087630267)}),
#  ('reciprocal_gen',
#   {'SSE': 0.5810348852080492,
#    'params': (0.9015482215897133,
#     1.6009849280375819,
#     0.0021890907748951093,
#     7.134297062689321e-31)}),
#  ('truncnorm_gen',
#   {'SSE': 0.5810348852080492,
#    'params': (0.9015482215897133,
#     1.6009849280375819,
#     0.0021890907748951093,
#     7.134297062689321e-31)}),
#  ('arcsine_gen',
#   {'SSE': 0.6187926784866435,
#    'params': (54.263133325097094, 24.73562772408398)}),
#  ('gengamma_gen',
#   {'SSE': 2.169070464174451,
#    'params': (1.7919193734793701,
#     0.3141974173931601,
#     54.263133325097094,
#     0.49300089985581874)}),
#  ('exponpow_gen',
#   {'SSE': 2.353192851281696,
#    'params': (0.1553616412575322, 54.263133325097094, 1.5848343280120842)}),
#  ('exponweib_gen',
#   {'SSE': 2.8504822157897816,
#    'params': (1.563789165113263,
#     0.3024156264140138,
#     54.263133325097094,
#     0.7970112519326721)}),
#  ('weibull_max_gen',
#   {'SSE': 3.133202866776807,
#    'params': (0.3497283307874748, 78.99874234638962, 1.3141441547432273)})]
