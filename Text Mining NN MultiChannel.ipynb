# %%
import os
from nltk.corpus import stopwords
from nltk import word_tokenize
from string import punctuation
import random

# %%
s = str.maketrans('', '', punctuation)
a = 'salam!@'
a.translate(s)
# Out:
# 'salam'

# %%
stop_words = stopwords.words('english')

# %%
negative_documents = []
max_len_negative = 0
for file in os.listdir('data/neg'):
    with open('data/neg/' + file) as f:
        text = f.read()
        tokens = word_tokenize(text)
        translator = str.maketrans('', '', punctuation)
        tokens = [w.translate(translator) for w in tokens]
        tokens = [w for w in tokens if not w in stop_words]
        if len(tokens) > max_len_negative:
            max_len_negative = len(tokens)
        negative_documents.append(' '.join(tokens))
len(negative_documents)
# Out:
# 1000

# %%
max_len_negative
# Out:
# 1400

# %%
positive_documents = []
max_len_positive = 0
for file in os.listdir('data/pos'):
    with open('data/pos/' + file) as f:
        text = f.read()
        tokens = word_tokenize(text)
        translator = str.maketrans('', '', punctuation)
        tokens = [w.translate(translator) for w in tokens]
        tokens = [w for w in tokens if not w in stop_words]
        if len(tokens) > max_len_positive:
            max_len_positive = len(tokens)
        positive_documents.append(' '.join(tokens))
len(positive_documents)
# Out:
# 1000

# %%
max_len_positive
# Out:
# 1693

# %%
max_len = max(max_len_negative, max_len_positive)

# %%
random.shuffle(negative_documents)
random.shuffle(positive_documents)

# %%
X_train = negative_documents[:800] + positive_documents[:800]

# %%
len(X_train)
# Out:
# 1600

# %%
y_train = [0 for _ in range(800)] + [1 for _ in range(800)]

# %%
len(y_train)
# Out:
# 1600

# %%
X_test = negative_documents[800:] + positive_documents[800:]
len(X_test)
# Out:
# 400

# %%
y_test = [0 for _ in range(200)] + [1 for _ in range(200)]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Embedding, Conv1D, MaxPool1D, Dropout
from tensorflow.keras.layers import concatenate

# %%
max_len
# Out:
# 1693

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
import pickle
with open('tokenizer.h5', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
tokenizer

# %%
vocab_len = len(tokenizer.word_index) + 1

# %%
vocab_len
# Out:
# 40483

# %%
encoded = tokenizer.texts_to_sequences(X_train)

# %%
encoded[0]
# Out:
# [1724,
#  491,
#  342,
#  610,
#  337,
#  1,
#  154,
#  10178,
#  18209,
#  1760,
#  18210,
#  6491,
#  86,
#  213,
#  9264,
#  402,
#  332,
#  1841,
#  825,
#  16,
#  159,
#  9265,
#  23913,
#  3101,
#  2,
#  22,
#  150,
#  14,
#  402,
#  123,
#  60,
#  4185,
#  9264,
#  1724,
#  458,
#  1941,
#  326,
#  52,
#  537,
#  67,
#  1,
#  656,
#  831,
#  5,
#  39,
#  25,
#  102,
#  17,
#  3420,
#  367,
#  96,
#  7,
#  10179,
#  1724,
#  2206,
#  1304,
#  7,
#  65,
#  54,
#  114,
#  2,
#  909,
#  76,
#  108,
#  1628,
#  6,
#  1724,
#  2,
#  30,
#  1097,
#  10,
#  848,
#  92,
#  15019,
#  35,
#  43,
#  92,
#  81,
#  22,
#  1870,
#  87,
#  35,
#  52,
#  44,
#  35,
#  1359,
#  1724,
#  128,
#  1284,
#  1,
#  521,
#  662,
#  848,
#  172,
#  18211,
#  518,
#  8482,
#  714,
#  314,
#  2511,
#  25,
#  715,
#  988,
#  2207,
#  87,
#  79,
#  246,
#  1,
#  67,
#  18210,
#  458,
#  1941,
#  2511,
#  657,
#  7,
#  188,
#  54,
#  1724,
#  76,
#  167,
#  11,
#  82,
#  160,
#  7,
#  65,
#  54,
#  30,
#  277,
#  44,
#  35,
#  19,
#  184,
#  15020,
#  13,
#  7,
#  214,
#  596,
#  8483,
#  421,
#  939,
#  19,
#  87,
#  71,
#  797,
#  126,
#  206,
#  338,
#  1,
#  4,
#  33,
#  5029,
#  1080,
#  197,
#  1,
#  7,
#  214,
#  610,
#  1224,
#  217,
#  467,
#  242,
#  1,
#  134,
#  848,
#  56,
#  731,
#  1,
#  6492,
#  1486,
#  114,
#  2,
#  22,
#  1225]

# %%
padded = pad_sequences(encoded, maxlen=max_len, padding='post')

# %%
padded.shape
# Out:
# (1600, 1693)

# %%
input1 = Input(shape=(max_len,))
embedding1 = Embedding(vocab_len, 100)(input1)
conv1 = Conv1D(filters=32, kernel_size=4, activation='relu')(embedding1)
drop1 = Dropout(0.5)(conv1)
pool1 = MaxPool1D(pool_size=2)(drop1)
flat1 = Flatten()(pool1)

input2 = Input(shape=(max_len,))
embedding2 = Embedding(vocab_len, 100)(input2)
conv2 = Conv1D(filters=32, kernel_size=6, activation='relu')(embedding2)
drop2 = Dropout(0.5)(conv2)
pool2 = MaxPool1D(pool_size=2)(drop2)
flat2= Flatten()(pool2)

input3 = Input(shape=(max_len,))
embedding3 = Embedding(vocab_len, 100)(input3)
conv3 = Conv1D(filters=32, kernel_size=8, activation='relu')(embedding3)
drop3 = Dropout(0.5)(conv3)
pool3 = MaxPool1D(pool_size=2)(drop3)
flat3 = Flatten()(pool3)

input4 = Input(shape=(max_len,))
embedding4 = Embedding(vocab_len, 100)(input4)
conv4 = Conv1D(filters=32, kernel_size=10, activation='relu')(embedding4)
drop4 = Dropout(0.5)(conv4)
pool4 = MaxPool1D(pool_size=2)(drop4)
flat4 = Flatten()(pool4)

conc = concatenate([flat1, flat2, flat3, flat4])

dense1 = Dense(10, activation='relu')(conc)
output = Dense(1, activation='sigmoid')(dense1)

# %%
model = Model(inputs=[input1, input2, input3, input4], outputs=output)

# %%
plot_model(model, show_shapes=True)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1693)]       0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1693)]       0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1693)]       0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 1693)]       0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1693, 100)    4048300     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1693, 100)    4048300     input_2[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1693, 100)    4048300     input_3[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1693, 100)    4048300     input_4[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1690, 32)     12832       embedding[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 1688, 32)     19232       embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1686, 32)     25632       embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1684, 32)     32032       embedding_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1690, 32)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1688, 32)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1686, 32)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1684, 32)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 845, 32)      0           dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 844, 32)      0           dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 843, 32)      0           dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 842, 32)      0           dropout_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 27040)        0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 27008)        0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 26976)        0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 26944)        0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 107968)       0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           1079690     concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            11          dense[0][0]
# ==================================================================================================
# Total params: 17,362,629
# Trainable params: 17,362,629
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
encoded_test = tokenizer.texts_to_sequences(X_test)
padded_test = pad_sequences(encoded_test, maxlen=max_len, padding='post')

# %%
padded_test.shape
# Out:
# (400, 1693)

# %%
import numpy as np

# %%
model.fit([padded, padded, padded, padded], np.array(y_train), epochs=10, batch_size=20, validation_data=([padded_test, padded_test, padded_test, padded_test], np.array(y_test)))
# Out:
# Epoch 1/10
# 80/80 [==============================] - 34s 426ms/step - loss: 0.6943 - accuracy: 0.5094 - val_loss: 0.6848 - val_accuracy: 0.5500
# Epoch 2/10
# 80/80 [==============================] - 33s 407ms/step - loss: 0.4965 - accuracy: 0.8238 - val_loss: 0.4360 - val_accuracy: 0.8125
# Epoch 3/10
# 80/80 [==============================] - 31s 387ms/step - loss: 0.0589 - accuracy: 0.9819 - val_loss: 0.3649 - val_accuracy: 0.8325
# Epoch 4/10
# 80/80 [==============================] - 31s 384ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4145 - val_accuracy: 0.8175
# Epoch 5/10
# 80/80 [==============================] - 31s 385ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3706 - val_accuracy: 0.8200
# Epoch 6/10
# 80/80 [==============================] - 31s 385ms/step - loss: 6.4391e-04 - accuracy: 1.0000 - val_loss: 0.3755 - val_accuracy: 0.8200
# Epoch 7/10
# 80/80 [==============================] - 31s 386ms/step - loss: 3.6582e-04 - accuracy: 1.0000 - val_loss: 0.4953 - val_accuracy: 0.7950
# Epoch 8/10
# 80/80 [==============================] - 31s 384ms/step - loss: 2.5600e-04 - accuracy: 1.0000 - val_loss: 0.4411 - val_accuracy: 0.8200
# Epoch 9/10
# 80/80 [==============================] - 31s 387ms/step - loss: 1.9323e-04 - accuracy: 1.0000 - val_loss: 0.3920 - val_accuracy: 0.8200
# Epoch 10/10
# 80/80 [==============================] - 31s 385ms/step - loss: 1.3924e-04 - accuracy: 1.0000 - val_loss: 0.3859 - val_accuracy: 0.8250

# %%
model.save('textcnn.h5')

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('textcnn.h5')

# %%
with open('tokenizer.h5', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
tokenizer.word_index
# Out:
# {'film': 1,
#  'nt': 2,
#  'movie': 3,
#  'one': 4,
#  'like': 5,
#  'even': 6,
#  'good': 7,
#  'time': 8,
#  'would': 9,
#  'story': 10,
#  'much': 11,
#  'character': 12,
#  'also': 13,
#  'get': 14,
#  'characters': 15,
#  'two': 16,
#  'first': 17,
#  'see': 18,
#  'well': 19,
#  'way': 20,
#  'could': 21,
#  'really': 22,
#  'make': 23,
#  'life': 24,
#  'plot': 25,
#  'little': 26,
#  'films': 27,
#  'people': 28,
#  'never': 29,
#  'bad': 30,
#  'scene': 31,
#  'man': 32,
#  'best': 33,
#  'new': 34,
#  'scenes': 35,
#  'many': 36,
#  'know': 37,
#  'movies': 38,
#  'great': 39,
#  'another': 40,
#  'director': 41,
#  'us': 42,
#  'go': 43,
#  'action': 44,
#  'love': 45,
#  'still': 46,
#  'something': 47,
#  'seems': 48,
#  'end': 49,
#  'made': 50,
#  'world': 51,
#  'work': 52,
#  'makes': 53,
#  'however': 54,
#  'back': 55,
#  'every': 56,
#  'though': 57,
#  'audience': 58,
#  'big': 59,
#  'gets': 60,
#  'take': 61,
#  'better': 62,
#  'enough': 63,
#  'seen': 64,
#  'performance': 65,
#  'around': 66,
#  'going': 67,
#  'may': 68,
#  'real': 69,
#  'years': 70,
#  'last': 71,
#  'role': 72,
#  'think': 73,
#  'things': 74,
#  'funny': 75,
#  'although': 76,
#  'comedy': 77,
#  'actually': 78,
#  'thing': 79,
#  'almost': 80,
#  'nothing': 81,
#  'say': 82,
#  'find': 83,
#  'look': 84,
#  'since': 85,
#  'played': 86,
#  'fact': 87,
#  'script': 88,
#  'right': 89,
#  'come': 90,
#  'john': 91,
#  'long': 92,
#  'ever': 93,
#  'show': 94,
#  'young': 95,
#  'cast': 96,
#  'plays': 97,
#  'comes': 98,
#  'old': 99,
#  'year': 100,
#  'original': 101,
#  'actors': 102,
#  'without': 103,
#  'point': 104,
#  'star': 105,
#  'part': 106,
#  'quite': 107,
#  'acting': 108,
#  'family': 109,
#  'away': 110,
#  'takes': 111,
#  'guy': 112,
#  'lot': 113,
#  'ca': 114,
#  'course': 115,
#  'least': 116,
#  'three': 117,
#  'screen': 118,
#  'interesting': 119,
#  'goes': 120,
#  'might': 121,
#  'effects': 122,
#  'anything': 123,
#  'day': 124,
#  'far': 125,
#  'minutes': 126,
#  'place': 127,
#  'trying': 128,
#  'must': 129,
#  'watch': 130,
#  'yet': 131,
#  'wife': 132,
#  'instead': 133,
#  'rather': 134,
#  'fun': 135,
#  'times': 136,
#  'bit': 137,
#  'job': 138,
#  'seem': 139,
#  'always': 140,
#  'hollywood': 141,
#  'picture': 142,
#  'special': 143,
#  'probably': 144,
#  'home': 145,
#  'making': 146,
#  'sense': 147,
#  'woman': 148,
#  'give': 149,
#  'want': 150,
#  'kind': 151,
#  'along': 152,
#  'sure': 153,
#  'set': 154,
#  'becomes': 155,
#  'pretty': 156,
#  'help': 157,
#  'series': 158,
#  'black': 159,
#  'gives': 160,
#  'everything': 161,
#  'actor': 162,
#  'high': 163,
#  'american': 164,
#  'together': 165,
#  'men': 166,
#  'given': 167,
#  'money': 168,
#  'become': 169,
#  'whole': 170,
#  'watching': 171,
#  'dialogue': 172,
#  'hard': 173,
#  'music': 174,
#  'everyone': 175,
#  'got': 176,
#  'feel': 177,
#  'wants': 178,
#  'sex': 179,
#  'perhaps': 180,
#  'less': 181,
#  'especially': 182,
#  'death': 183,
#  'done': 184,
#  'next': 185,
#  'moments': 186,
#  'whose': 187,
#  'performances': 188,
#  'father': 189,
#  'play': 190,
#  'couple': 191,
#  'humor': 192,
#  'different': 193,
#  'put': 194,
#  'horror': 195,
#  'lost': 196,
#  'rest': 197,
#  'completely': 198,
#  'looks': 199,
#  'mind': 200,
#  'left': 201,
#  'city': 202,
#  'simply': 203,
#  'reason': 204,
#  'anyone': 205,
#  '2': 206,
#  'shows': 207,
#  'let': 208,
#  'case': 209,
#  'entire': 210,
#  'looking': 211,
#  'main': 212,
#  'michael': 213,
#  'ending': 214,
#  'girl': 215,
#  'small': 216,
#  'turns': 217,
#  'getting': 218,
#  'mother': 219,
#  'found': 220,
#  'david': 221,
#  'either': 222,
#  'human': 223,
#  'alien': 224,
#  'friend': 225,
#  'else': 226,
#  'several': 227,
#  'someone': 228,
#  'town': 229,
#  'problem': 230,
#  'soon': 231,
#  'half': 232,
#  'night': 233,
#  'evil': 234,
#  'line': 235,
#  'school': 236,
#  'unfortunately': 237,
#  'friends': 238,
#  'james': 239,
#  'comic': 240,
#  'use': 241,
#  'house': 242,
#  'true': 243,
#  'later': 244,
#  'idea': 245,
#  'keep': 246,
#  'sequence': 247,
#  'begins': 248,
#  'name': 249,
#  'based': 250,
#  'group': 251,
#  'tv': 252,
#  'final': 253,
#  'stars': 254,
#  'tries': 255,
#  'written': 256,
#  'relationship': 257,
#  'thought': 258,
#  'playing': 259,
#  'works': 260,
#  'behind': 261,
#  'person': 262,
#  'believe': 263,
#  'dead': 264,
#  'wrong': 265,
#  'children': 266,
#  'certainly': 267,
#  'finally': 268,
#  'named': 269,
#  'second': 270,
#  'head': 271,
#  'used': 272,
#  'maybe': 273,
#  'called': 274,
#  'often': 275,
#  'able': 276,
#  'said': 277,
#  'kids': 278,
#  'nice': 279,
#  'despite': 280,
#  'finds': 281,
#  'tell': 282,
#  'moment': 283,
#  'seeing': 284,
#  'including': 285,
#  'book': 286,
#  'run': 287,
#  'perfect': 288,
#  'turn': 289,
#  'style': 290,
#  'directed': 291,
#  'full': 292,
#  'live': 293,
#  'hand': 294,
#  'start': 295,
#  'past': 296,
#  'boy': 297,
#  'running': 298,
#  'supposed': 299,
#  'son': 300,
#  'lines': 301,
#  'kevin': 302,
#  'starts': 303,
#  'days': 304,
#  'need': 305,
#  'summer': 306,
#  'side': 307,
#  'lives': 308,
#  'dark': 309,
#  'robert': 310,
#  'entertaining': 311,
#  'mr': 312,
#  'game': 313,
#  'matter': 314,
#  'fight': 315,
#  'war': 316,
#  'worth': 317,
#  'worst': 318,
#  'problems': 319,
#  'exactly': 320,
#  'video': 321,
#  'team': 322,
#  'nearly': 323,
#  'upon': 324,
#  'title': 325,
#  'try': 326,
#  'care': 327,
#  'daughter': 328,
#  'example': 329,
#  'throughout': 330,
#  'eyes': 331,
#  'car': 332,
#  'face': 333,
#  'production': 334,
#  'opening': 335,
#  'camera': 336,
#  'drama': 337,
#  'hour': 338,
#  'short': 339,
#  'review': 340,
#  'simple': 341,
#  'act': 342,
#  'beautiful': 343,
#  'shot': 344,
#  'violence': 345,
#  'early': 346,
#  'fine': 347,
#  'order': 348,
#  'question': 349,
#  'disney': 350,
#  'obvious': 351,
#  'white': 352,
#  'knows': 353,
#  'already': 354,
#  'screenplay': 355,
#  'others': 356,
#  'roles': 357,
#  'tom': 358,
#  'sort': 359,
#  'top': 360,
#  'boring': 361,
#  'classic': 362,
#  'ship': 363,
#  'sometimes': 364,
#  'hit': 365,
#  'scream': 366,
#  'supporting': 367,
#  'kill': 368,
#  'deep': 369,
#  'known': 370,
#  'women': 371,
#  'version': 372,
#  'earth': 373,
#  'direction': 374,
#  'four': 375,
#  'sequences': 376,
#  'save': 377,
#  'attempt': 378,
#  'jackie': 379,
#  'king': 380,
#  'joe': 381,
#  'body': 382,
#  'lee': 383,
#  'coming': 384,
#  'brother': 385,
#  'strong': 386,
#  'heart': 387,
#  'guys': 388,
#  'wo': 389,
#  'ends': 390,
#  'van': 391,
#  'romantic': 392,
#  'involving': 393,
#  'truly': 394,
#  'major': 395,
#  'jokes': 396,
#  'space': 397,
#  'lead': 398,
#  'beginning': 399,
#  'thriller': 400,
#  'saw': 401,
#  'involved': 402,
#  'smith': 403,
#  'says': 404,
#  'husband': 405,
#  'possible': 406,
#  'result': 407,
#  'tells': 408,
#  'hope': 409,
#  'jack': 410,
#  'happens': 411,
#  'yes': 412,
#  'peter': 413,
#  'sets': 414,
#  'genre': 415,
#  'stupid': 416,
#  'emotional': 417,
#  'future': 418,
#  'extremely': 419,
#  'career': 420,
#  'sound': 421,
#  'child': 422,
#  'murder': 423,
#  'particularly': 424,
#  'voice': 425,
#  'close': 426,
#  'mostly': 427,
#  'paul': 428,
#  'fiction': 429,
#  'stop': 430,
#  'appears': 431,
#  'wonder': 432,
#  'york': 433,
#  'eventually': 434,
#  'material': 435,
#  'police': 436,
#  'manages': 437,
#  'five': 438,
#  'quickly': 439,
#  'god': 440,
#  'novel': 441,
#  'note': 442,
#  'hours': 443,
#  'worse': 444,
#  'aliens': 445,
#  'science': 446,
#  'room': 447,
#  'meet': 448,
#  'attention': 449,
#  'planet': 450,
#  'experience': 451,
#  'fall': 452,
#  'mean': 453,
#  'elements': 454,
#  'living': 455,
#  'fans': 456,
#  'killer': 457,
#  'de': 458,
#  'taking': 459,
#  'falls': 460,
#  'guess': 461,
#  'expect': 462,
#  'lack': 463,
#  'level': 464,
#  'oscar': 465,
#  'george': 466,
#  'power': 467,
#  'chance': 468,
#  'none': 469,
#  'theater': 470,
#  'alone': 471,
#  'laughs': 472,
#  'leads': 473,
#  'girls': 474,
#  'piece': 475,
#  'whether': 476,
#  'features': 477,
#  'obviously': 478,
#  'killed': 479,
#  'interest': 480,
#  'wild': 481,
#  'bring': 482,
#  'usually': 483,
#  'number': 484,
#  'happen': 485,
#  'battle': 486,
#  'across': 487,
#  'except': 488,
#  'easy': 489,
#  'premise': 490,
#  'attempts': 491,
#  'success': 492,
#  'enjoy': 493,
#  'feature': 494,
#  'needs': 495,
#  'single': 496,
#  'tale': 497,
#  'feeling': 498,
#  '1': 499,
#  'among': 500,
#  'talk': 501,
#  'within': 502,
#  'taken': 503,
#  'word': 504,
#  'deal': 505,
#  'williams': 506,
#  'wonderful': 507,
#  'released': 508,
#  'meets': 509,
#  'dr': 510,
#  'hero': 511,
#  'robin': 512,
#  'feels': 513,
#  'change': 514,
#  'score': 515,
#  'mission': 516,
#  'seemed': 517,
#  'basically': 518,
#  'giving': 519,
#  'parents': 520,
#  'serious': 521,
#  'history': 522,
#  'chris': 523,
#  'easily': 524,
#  'impressive': 525,
#  'apparently': 526,
#  'laugh': 527,
#  'dog': 528,
#  'viewer': 529,
#  'form': 530,
#  'happy': 531,
#  'local': 532,
#  'talent': 533,
#  'late': 534,
#  'brings': 535,
#  'parts': 536,
#  'hell': 537,
#  'forced': 538,
#  'leave': 539,
#  'release': 540,
#  'television': 541,
#  'working': 542,
#  'runs': 543,
#  'poor': 544,
#  'call': 545,
#  'somehow': 546,
#  'recent': 547,
#  'certain': 548,
#  'stuff': 549,
#  'sequel': 550,
#  'entertainment': 551,
#  'difficult': 552,
#  'crew': 553,
#  'complete': 554,
#  'figure': 555,
#  '3': 556,
#  'cool': 557,
#  'girlfriend': 558,
#  'told': 559,
#  'presence': 560,
#  'begin': 561,
#  'absolutely': 562,
#  'mystery': 563,
#  'intelligent': 564,
#  'middle': 565,
#  'hilarious': 566,
#  'personal': 567,
#  'went': 568,
#  'turned': 569,
#  'bob': 570,
#  'brothers': 571,
#  'decides': 572,
#  'ago': 573,
#  'return': 574,
#  'blood': 575,
#  'harry': 576,
#  'bill': 577,
#  'art': 578,
#  'due': 579,
#  'america': 580,
#  'events': 581,
#  'sam': 582,
#  'somewhat': 583,
#  'using': 584,
#  'general': 585,
#  'came': 586,
#  'filmmakers': 587,
#  'writing': 588,
#  'remember': 589,
#  'company': 590,
#  'jim': 591,
#  'surprise': 592,
#  'stories': 593,
#  'amazing': 594,
#  'crime': 595,
#  'uses': 596,
#  'anyway': 597,
#  'quality': 598,
#  'prison': 599,
#  'words': 600,
#  'computer': 601,
#  'die': 602,
#  'reality': 603,
#  'previous': 604,
#  'credits': 605,
#  'project': 606,
#  'william': 607,
#  'party': 608,
#  'wars': 609,
#  'cop': 610,
#  'oh': 611,
#  'straight': 612,
#  'situation': 613,
#  'suspense': 614,
#  'rich': 615,
#  'strange': 616,
#  'message': 617,
#  'jones': 618,
#  'batman': 619,
#  'ben': 620,
#  'light': 621,
#  'carter': 622,
#  'business': 623,
#  'surprisingly': 624,
#  'writer': 625,
#  'following': 626,
#  'office': 627,
#  'sweet': 628,
#  'popular': 629,
#  'towards': 630,
#  'giant': 631,
#  'romance': 632,
#  'add': 633,
#  'dramatic': 634,
#  'create': 635,
#  'talking': 636,
#  'ryan': 637,
#  'starring': 638,
#  'questions': 639,
#  'former': 640,
#  'similar': 641,
#  'effective': 642,
#  'important': 643,
#  'ways': 644,
#  'successful': 645,
#  'read': 646,
#  'sexual': 647,
#  'flick': 648,
#  'age': 649,
#  'annoying': 650,
#  'seriously': 651,
#  'water': 652,
#  'clever': 653,
#  'martin': 654,
#  'kid': 655,
#  'brilliant': 656,
#  'usual': 657,
#  'definitely': 658,
#  'ones': 659,
#  'powerful': 660,
#  'murphy': 661,
#  'means': 662,
#  'beyond': 663,
#  'leaving': 664,
#  'took': 665,
#  'smart': 666,
#  'enjoyable': 667,
#  'latest': 668,
#  'visual': 669,
#  'wedding': 670,
#  'cut': 671,
#  'type': 672,
#  'gone': 673,
#  'audiences': 674,
#  'leaves': 675,
#  'move': 676,
#  'felt': 677,
#  'nature': 678,
#  'moving': 679,
#  'opens': 680,
#  'solid': 681,
#  'excellent': 682,
#  'thinking': 683,
#  'predictable': 684,
#  'max': 685,
#  'likely': 686,
#  'shots': 687,
#  'effect': 688,
#  'large': 689,
#  'secret': 690,
#  'bond': 691,
#  'doubt': 692,
#  'country': 693,
#  'mark': 694,
#  'third': 695,
#  'happened': 696,
#  'actress': 697,
#  'scary': 698,
#  'unlike': 699,
#  'clear': 700,
#  'plan': 701,
#  'cinema': 702,
#  'woody': 703,
#  'rock': 704,
#  'musical': 705,
#  'villain': 706,
#  'particular': 707,
#  'allen': 708,
#  'break': 709,
#  'married': 710,
#  'follow': 711,
#  'cameron': 712,
#  'learn': 713,
#  'points': 714,
#  'potential': 715,
#  'immediately': 716,
#  'motion': 717,
#  'viewers': 718,
#  'present': 719,
#  'subject': 720,
#  '4': 721,
#  'saying': 722,
#  'slow': 723,
#  'neither': 724,
#  'perfectly': 725,
#  'red': 726,
#  'fails': 727,
#  'inside': 728,
#  'drug': 729,
#  'r': 730,
#  'exciting': 731,
#  'stay': 732,
#  'animated': 733,
#  'tim': 734,
#  'huge': 735,
#  'created': 736,
#  'government': 737,
#  'follows': 738,
#  'simon': 739,
#  'force': 740,
#  'otherwise': 741,
#  'scott': 742,
#  'richard': 743,
#  'understand': 744,
#  'agent': 745,
#  'filled': 746,
#  'near': 747,
#  'realize': 748,
#  'impossible': 749,
#  'dream': 750,
#  'mess': 751,
#  'bruce': 752,
#  'pay': 753,
#  'brought': 754,
#  'merely': 755,
#  'familiar': 756,
#  'frank': 757,
#  'truth': 758,
#  'overall': 759,
#  'ultimately': 760,
#  'bunch': 761,
#  'offers': 762,
#  'steven': 763,
#  'talented': 764,
#  'liked': 765,
#  'million': 766,
#  'appear': 767,
#  'members': 768,
#  'l': 769,
#  'credit': 770,
#  'decent': 771,
#  'heard': 772,
#  'park': 773,
#  'favorite': 774,
#  'dumb': 775,
#  'cold': 776,
#  'tarzan': 777,
#  'political': 778,
#  'queen': 779,
#  'keeps': 780,
#  'wanted': 781,
#  'steve': 782,
#  'trouble': 783,
#  'state': 784,
#  'fan': 785,
#  'slightly': 786,
#  'escape': 787,
#  'various': 788,
#  'ten': 789,
#  'studio': 790,
#  'stone': 791,
#  'chase': 792,
#  'effort': 793,
#  'entirely': 794,
#  'actual': 795,
#  'trek': 796,
#  '10': 797,
#  'rating': 798,
#  'depth': 799,
#  'purpose': 800,
#  'box': 801,
#  'ridiculous': 802,
#  'biggest': 803,
#  'soundtrack': 804,
#  'nick': 805,
#  'focus': 806,
#  'animation': 807,
#  'hands': 808,
#  'memorable': 809,
#  'fear': 810,
#  'fairly': 811,
#  'truman': 812,
#  'earlier': 813,
#  'totally': 814,
#  'fast': 815,
#  'law': 816,
#  'wait': 817,
#  'situations': 818,
#  'view': 819,
#  'west': 820,
#  'humans': 821,
#  'element': 822,
#  'open': 823,
#  'expected': 824,
#  'killing': 825,
#  'today': 826,
#  'eddie': 827,
#  'cinematic': 828,
#  'army': 829,
#  'chemistry': 830,
#  'sounds': 831,
#  'sees': 832,
#  'whatever': 833,
#  'control': 834,
#  'moves': 835,
#  'gave': 836,
#  'spend': 837,
#  'beauty': 838,
#  'eye': 839,
#  'aspect': 840,
#  'society': 841,
#  'atmosphere': 842,
#  'typical': 843,
#  'ask': 844,
#  'outside': 845,
#  'female': 846,
#  'cheap': 847,
#  'dull': 848,
#  'suddenly': 849,
#  'song': 850,
#  'approach': 851,
#  'sean': 852,
#  'ability': 853,
#  'central': 854,
#  'silly': 855,
#  'screenwriter': 856,
#  'terrible': 857,
#  'indeed': 858,
#  'constantly': 859,
#  'jerry': 860,
#  'gun': 861,
#  'private': 862,
#  'waste': 863,
#  'thinks': 864,
#  'puts': 865,
#  'greatest': 866,
#  'british': 867,
#  'tarantino': 868,
#  'sister': 869,
#  'charm': 870,
#  'hate': 871,
#  'tone': 872,
#  'race': 873,
#  'meanwhile': 874,
#  'teen': 875,
#  'mike': 876,
#  'critics': 877,
#  'ii': 878,
#  'e': 879,
#  'theme': 880,
#  'jackson': 881,
#  'forget': 882,
#  'brown': 883,
#  'recently': 884,
#  'college': 885,
#  'member': 886,
#  'rated': 887,
#  'background': 888,
#  'mary': 889,
#  'ideas': 890,
#  'showing': 891,
#  'complex': 892,
#  'incredibly': 893,
#  'band': 894,
#  'cinematography': 895,
#  'okay': 896,
#  'telling': 897,
#  'setting': 898,
#  'subplot': 899,
#  'longer': 900,
#  'amusing': 901,
#  'thanks': 902,
#  'dreams': 903,
#  'lots': 904,
#  'impact': 905,
#  'convincing': 906,
#  'ride': 907,
#  'grace': 908,
#  'hold': 909,
#  'quick': 910,
#  'english': 911,
#  'club': 912,
#  'scifi': 913,
#  'street': 914,
#  'amount': 915,
#  'b': 916,
#  'delivers': 917,
#  'sit': 918,
#  'seemingly': 919,
#  'tension': 920,
#  'believable': 921,
#  'possibly': 922,
#  'shown': 923,
#  'modern': 924,
#  'considering': 925,
#  'clearly': 926,
#  'reasons': 927,
#  'etc': 928,
#  'free': 929,
#  'air': 930,
#  'boys': 931,
#  'leading': 932,
#  'lies': 933,
#  'asks': 934,
#  'wrote': 935,
#  'lucas': 936,
#  'wish': 937,
#  'opportunity': 938,
#  'system': 939,
#  'chan': 940,
#  'appearance': 941,
#  'class': 942,
#  'consider': 943,
#  'spent': 944,
#  'subtle': 945,
#  'seven': 946,
#  'famous': 947,
#  'looked': 948,
#  'plenty': 949,
#  'brief': 950,
#  'key': 951,
#  'choice': 952,
#  'baby': 953,
#  'road': 954,
#  'cute': 955,
#  'six': 956,
#  'toy': 957,
#  'imagine': 958,
#  'knew': 959,
#  'front': 960,
#  'highly': 961,
#  'mysterious': 962,
#  'decide': 963,
#  'minor': 964,
#  'common': 965,
#  'leader': 966,
#  'pull': 967,
#  'list': 968,
#  'willis': 969,
#  'casting': 970,
#  'flat': 971,
#  'images': 972,
#  'alive': 973,
#  'contains': 974,
#  'slowly': 975,
#  'worked': 976,
#  '000': 977,
#  'green': 978,
#  'awful': 979,
#  'heavy': 980,
#  'stand': 981,
#  'onto': 982,
#  'j': 983,
#  'writers': 984,
#  'trip': 985,
#  'store': 986,
#  'carrey': 987,
#  'wasted': 988,
#  'write': 989,
#  'hardly': 990,
#  'admit': 991,
#  'fire': 992,
#  'joke': 993,
#  'becoming': 994,
#  'songs': 995,
#  'violent': 996,
#  'julia': 997,
#  'climax': 998,
#  'u': 999,
#  'travolta': 1000,
#  ...}

# %%
txt = '''
boy , what a great movie ! ! 
keanu reeves and morgan freeman acting together , the director of the fugitive ( andrew davis ) back again to give us another thriller , and the beautiful rachel stealing beauty weisz thrown in to boot . 
how could this not be a blockbuster ? 
all die-hard keanu reeves fans , read on . 
ol " much ado about nothing " plays eddie kasalivich , a machinist studying at the university of chicago . 
to help pay for the rent , he takes on this job making the machinery for a hydrogen project being conducted by the university . 
by happy coincidence , he also happens to stumble on the solution to the final problem and thus is the only one who knows the key to performing this feat of miracle physics . 
this project holds great promise : taking hydrogen from water and giving out more energy than is put in . 
a potential solution to the earth's energy problems without the pollution cost . 
surely nobody could have any problems with that ? 
morgan freeman is paul shannon , the project's sponsor . 
he works for a very powerful organization that disagrees with the paternal project leader as to how quickly technology should be released to the public . 
he figures the world will disintegrate into anarchy if the results of the project are released too quickly . 
so he murders the project leader , blows up the project ( great but short scene here , sort of like a mini id4 city-devastation thing ) and tries to simulate the experiment at some other hi-tech hush-hush location . 
unfortunately , our intrepid machinist and an english physicist ( weisz ) manage to get away and now follows a fugitive-like chase using a not too dissimilar rehash of that movie script . 
this movie is just dying for a comparison with " the fugitive " . 
both movies use chicago as the main city and since the place doesn't change much , i guess we can't really blame the setting for the paucity of atmosphere . 
the trouble here is that where the fugitive had harrison ford and tommy lee jones , chain reaction only has keanu reeves and fred ward . 
credit to them , but we aren't really given much of a chance to empathise with the characters . 
where ford was able to work within the confines of the movie to evoke sympathy , eddie kasalivich just doesn9t seem very believeable and reeves' character is never given the time to develop . 
it might have been a better investment in film to give the characters more depth and spend less time on the chase sequences , which frankly , get quite boring after a while . 
harrison ford was " the man against the world . " 
he was alone in a world where he didn't know who to trust and it came across real well . 
in chain reaction , keanu reeves isn't alone . 
now that would be fine if the fleeing couple had some chemistry and could really portray some paranoia , vulnerability and confusion . 
we don't get this . 
we get him thinking he's still in speed , only now our sandra bullock has an english accent , probably doesn't drive a bus , and hardly contributes anything to the movie . 
the producers here probably thought , " hey , what if keanu and rachel don't hit it off too well ? 
let's rope in that morgan to help us out . " 
well , keanu and rachel didn't hit it off well on the screen , and most unfortunately , morgan freeman doesn't help much either . 
the only thing we come to really know of paul shannon is that he always has a full load of cigars in his cigar holder . 
it's not really his fault . 
once again , andrew davis just doesn't take the time to build his characters . 
someone must have convinced him that this time round , cinema dollars are best earned by making the movie run like a headless chicken . 
the flying inkpot rating system : * wait for the tv2 broadcast . 
 * * a little creaky , but still better than staying at home with gotcha ! 
 * * * pretty good , bring a friend . 
 * * * * amazing , potent stuff . 
 * * * * * perfection . 
see it twice . 
'''

# %%
encoded_txt = tokenizer.texts_to_sequences([txt])
padded_txt = pad_sequences(encoded_txt, maxlen=max_len, padding='post')

# %%
padded_txt.shape
# Out:
# (1, 1693)

# %%
model.predict([padded_txt, padded_txt, padded_txt, padded_txt])
# Out:
# array([[0.00367927]], dtype=float32)

# %%
model.predict([padded_txt, padded_txt, padded_txt, padded_txt])[0][0]
# Out:
# 0.0036792657

# %%
if (model.predict([padded_txt, padded_txt, padded_txt, padded_txt])[0][0] < 0.5):
    print('negative')
else:
    print('positive')
# Out:
# negative
